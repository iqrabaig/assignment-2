# %%
 //newton raphson method
    import numpy as np
import matplotlib.pyplot as plt
 
def newton(fn,dfn,x,tol,maxiter):    
    for i in range(maxiter):   
    
        xnew = x - fn(x)/dfn(x)  
        if abs(xnew-x)<tol:                         
            break    
        x = xnew    
    return xnew, i

y = lambda x: 2*x**2-5*x+3     #
dy = lambda x : 6*x**2-9.5      

x, n = newton(y, dy, 0.4, 0.0001, 100)    
print('the root is %.3f at %d iterations.'%(x,n))
# Out:
# the root is 1.000 at 24 iterations.

# %%
x = np.linspace(-2,2,100)
y =  4*x-5

plt.plot(x,y)
plt.grid()
plt.xlabel('x-axis',fontsize=15)
plt.ylabel('y-axis',fontsize=15)
# Out:
#   File "C:\Users\PCPLAN~1\AppData\Local\Temp/ipykernel_192/2025101363.py", line 3
#     y = 2*x**2-5x+3
#                 ^
# SyntaxError: invalid syntax

# %%
x = np.linspace(1.5,1,100) 
y = 2*x**2-5*x+3
plt.plot(x,y)
plt.grid()
plt.xlabel('x-axis',fontsize=15)
plt.ylabel('y-axis',fontsize=15)
# Out:
# Text(0, 0.5, 'y-axis')

# %%
def secant(fn,x1,x2,tol,maximum): 
    for i in range(maximum):
        xnew  = x2 - (x2-x1)/(fn(x2)-fn(x1))*fn(x2) 
        if abs(xnew-x2) < tol: 
            break
        else:
            x1 = x2
            x2 = xnew
    else:
        print('you are doing wrong')
    return xnew, i

f = lambda x: 2*x**2 - 5*x + 3 # funtion

x1 = float(input('enter x1: ')) 
x2 = float(input('enter x2: '))

r, n = secant(f,x1,x2,1.0e-6,100) 

print('Root = %f at %d iterations'%(r,n))
# Out:
# enter x1: 1.2
# enter x2: 1.3
# Root = 1.300781 at 2 iterations

# %%
x = np.linspace(1.5,1,100)
y =  2*x**2 - 5*x + 3 
plt.plot(x,y)
plt.grid()
plt.xlabel('x-axis',fontsize=10)
plt.ylabel('y-axis',fontsize=10)
# Out:
# Text(0, 0.5, 'y-axis')

# %%
f=lambda x: 0.1*x*5 - 0.2*x*3 + 0.1*x - 0.2
x = 0.1
h = 0.1
df1 = 0.09405
df2 = -0.118
print("\t f'(x)\t\t err\t\t f''(x)\t\t err")
dff1 = (f(x+h)-f(x))/h
dff2 = (f(x+2*h)-2*f(x+h)+f(x))/h**2
print("FFD\t% .8f\t% .8f\t% .8f\t% .8f"%(dff1,dff1-df1,dff2,dff2-df2))
dff1 = (f(x)-f(x-h))/h
dff2 = (f(x)-2*f(x-h)+f(x-2*h))/h**2
print("BFD\t% .8f\t% .8f\t% .8f\t%  .8f"%(dff1,dff1-df1,dff2,dff2-df2))
dff1 = (f(x+h)-f(x-h))/(2*h)
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2
print("CFD\t% .8f\t% .8f\t% .8f\t% .8f"%(dff1,dff1-df1,dff2,dff2-df2))
# Out:
# 	 f'(x)		 err		 f''(x)		 err
# FFD	 0.00000000	-0.09405000	-0.00000000	 0.11800000
# BFD	 0.00000000	-0.09405000	 0.00000000	 0.11800000
# CFD	 0.00000000	-0.09405000	 0.00000000	 0.11800000

# %%
 import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.01
#will create an array of elements between -1 and 1 having 50 equal
x = np.linspace(-1,1,50)
# central diffrences 


dff1 = (f(x+h)-f(x-h))/(2*h)
dff2 = (f(x+h)-2*f(x)+f(x-h))/h**2
#plot
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
 import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.01
#will create an array of elements between -1 and 1 having 50 equal
x = np.linspace(-1,1,50)
# forward difference

dff1 = (f(x+h)  -  f(x))/h
dff2 = (f(x+2*h) - 2*f(x+h) + f(x))/h**2



#plot
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
f=lambda x: 0.1*x**5 - 0.2*x**3 + 0.1*x - 0.2

h = 0.01
#will create an array of elements between -1 and 1 having 50 equal
x = np.linspace(-1,1,50)
# backward


dff1 = (f(x) - f(x-h))/h
dff2 = (f(x) - 2*f(x-h) + f(x-2*h) )/h**2

#plot
plt.plot(x,f(x),'-k',x,dff1,'--b',x,dff2,'-.r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(["f(x)","f'(x)","f''(x)"])
plt.grid()
